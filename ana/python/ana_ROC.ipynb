# %%
import uproot
import matplotlib.pyplot as plt
import numpy as np

# %%
data1 = np.loadtxt('./../../txt_file/Mx2_150/ROC1.txt')
data2 = np.loadtxt('./../../txt_file/Mx2_150/ROC2.txt')
data3 = np.loadtxt('./../../txt_file/Mx2_150/ROC3.txt')
data4 = np.loadtxt('./../../txt_file/Mx2_150/ROC4.txt')
data5 = np.loadtxt('./../../txt_file/Mx2_150/ROC5.txt')
data10 = np.loadtxt('./../../txt_file/Mx2_150/ROC10.txt')
data15 = np.loadtxt('./../../txt_file/Mx2_150/ROC15.txt')

# %%
plt.figure(figsize=(10,10))
plt.plot(data1[:,0],data1[:,1],"*-",label = r'$log10(3D_{sig})$<0.2')
plt.plot(data2[:,0],data2[:,1],"*-",label = r'$log10(3D_{sig})$<0.3')
plt.plot(data3[:,0],data3[:,1],"*-",label = r'$log10(3D_{sig})$<0.4')
plt.plot(data4[:,0],data4[:,1],"*-",label = r'$log10(3D_{sig})$<0.5')
plt.plot(data5[:,0],data5[:,1],"*-",label = r'$log10(3D_{sig})$<0.6')
#plt.plot(data10[:,0],data10[:,1],"*-",label =r'$log10(3D_{sig})$<1.1')
#plt.plot(data15[:,0],data15[:,1],"*-",label = r'$log10(3D_{sig})$<1.6')
plt.legend(fontsize=15)
plt.title("Mx2_150 ROC curve",fontsize=20)
plt.xlabel('Sig Efficiency',fontsize=20)
plt.ylabel('Bkg rejection',fontsize=20)
plt.grid()
plt.savefig("150.png")

# %%
Mx2_1 = uproot.open("./../../../root_file/Ztoee/test1.root")
Mx2_50
Mx2_150
DYHT70
DYHT100
DYHT200
DYHT400
DYHT600
DYHT800

# %%
file
# Out:
# <ReadOnlyDirectory '/' at 0x7fb42c0fba30>

# %%
file.keys()
# Out:
# ['T_event;1',
#  'PUdz;1',
#  'h_dzError;1',
#  'h_dxyError;1',
#  'hmet;1',
#  'dilepton_pT_met;1',
#  'h_aph;1',
#  'h_aphmax;1',
#  'h_aphmin;1',
#  'h_aph026;1',
#  'h_jet_n;1',
#  'h_jet_rank;1',
#  'h_ele_n;1',
#  'h_mu_n;1',
#  'h_tau_n;1',
#  'h_nTracks;1',
#  'h_track_phi;1',
#  'h_track_dr;1',
#  'h_track_draf;1',
#  'h_jet_eta;1',
#  'h_jet_pt;1',
#  'Teacketa;1',
#  'h_AK4mass;1',
#  'Z_massee;1',
#  'dilepton_pT;1',
#  'h_ee_event;1',
#  'Chi3Dlog;1',
#  'Chi3Dlogaf;1',
#  'Chi3D;1',
#  'Chi3DPaperlog;1',
#  'Chi2Dlog;1',
#  'h_eventWeight;1',
#  'h_event;1',
#  'h_ee_stu_event;1',
#  'h_ee_npass;1',
#  'h_SumWeight;1',
#  'gen_chi2numb;1',
#  'gen_dquarknumb;1',
#  'gen_eenumber;1',
#  'match_dquarknumb;1',
#  'ratioTrackPt;1',
#  'h_jet_dr_d2;1',
#  'h_jet_dr_d3;1',
#  'Thinjet_pT;1',
#  'h_MCweight;1',
#  'h_jet_hadronless_0_2Flavour;1',
#  'h_jet_hadronbig0_2Flavour;1',
#  'h_tau_thisdr;1',
#  'h_tau_thatdr;1',
#  'h_mt2;1',
#  'h_aphmin_Opt0;1',
# ...

# %%
file["h_aphmin_Opt0"]
# Out:
# <TH1F (version 3) at 0x7fb42c114880>
